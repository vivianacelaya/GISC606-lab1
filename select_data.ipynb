# %%
import os 
import pandas as pd
import earthpy as et

# %%
os.chdir(os.path.join(et.io.HOME,"earth-analytics"))

# %%
fname = os.path.join("data", "earthpy-downloads", 
                     "avg-precip-months-seasons.csv")

avg_monthly_precip = pd.read_csv(fname)

avg_monthly_precip
# Out:
#    months  precip seasons
# 0     Jan    0.70  Winter
# 1     Feb    0.75  Winter
# 2     Mar    1.85  Spring
# 3     Apr    2.93  Spring
# 4     May    3.05  Spring
# 5    June    2.02  Summer
# 6    July    1.93  Summer
# 7     Aug    1.62  Summer
# 8    Sept    1.84    Fall
# 9     Oct    1.31    Fall
# 10    Nov    1.39    Fall
# 11    Dec    0.84  Winter

# %%
avg_monthly_precip.iloc[0:1, 0:1]
# Out:
#   months
# 0    Jan

# %%
avg_monthly_precip.iloc[0:2, 0:1]
# Out:
#   months
# 0    Jan
# 1    Feb

# %%
avg_monthly_precip.iloc[0:1, 0:2]
# Out:
#   months  precip
# 0    Jan     0.7

# %%
avg_monthly_precip.iloc[0:1, :]
# Out:
#   months  precip seasons
# 0    Jan     0.7  Winter

# %%
avg_monthly_precip.iloc[:, 0:1]
# Out:
#    months
# 0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5    June
# 6    July
# 7     Aug
# 8    Sept
# 9     Oct
# 10    Nov
# 11    Dec

# %%
avg_monthly_precip_index = avg_monthly_precip.set_index("months")

avg_monthly_precip_index
# Out:
#         precip seasons
# months
# Jan       0.70  Winter
# Feb       0.75  Winter
# Mar       1.85  Spring
# Apr       2.93  Spring
# May       3.05  Spring
# June      2.02  Summer
# July      1.93  Summer
# Aug       1.62  Summer
# Sept      1.84    Fall
# Oct       1.31    Fall
# Nov       1.39    Fall
# Dec       0.84  Winter

# %%
avg_monthly_precip_index[["months"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 avg_monthly_precip_index[["months"]]
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/.python/current/lib/python3.10/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['months'], dtype='object')] are in the [columns]"

# %%
avg_monthly_precip_index.loc[["Aug"]]
# Out:
#         precip seasons
# months
# Aug       1.62  Summer

# %%
avg_monthly_precip["months"]
# Out:
# 0      Jan
# 1      Feb
# 2      Mar
# 3      Apr
# 4      May
# 5     June
# 6     July
# 7      Aug
# 8     Sept
# 9      Oct
# 10     Nov
# 11     Dec
# Name: months, dtype: object

# %%
avg_monthly_precip_text = avg_monthly_precip[['months', 'seasons']]

avg_monthly_precip_text
# Out:
#    months seasons
# 0     Jan  Winter
# 1     Feb  Winter
# 2     Mar  Spring
# 3     Apr  Spring
# 4     May  Spring
# 5    June  Summer
# 6    July  Summer
# 7     Aug  Summer
# 8    Sept    Fall
# 9     Oct    Fall
# 10    Nov    Fall
# 11    Dec  Winter

# %%
avg_monthly_precip[avg_monthly_precip["seasons"] == "Summer"]
# Out:
#   months  precip seasons
# 5   June    2.02  Summer
# 6   July    1.93  Summer
# 7    Aug    1.62  Summer

# %%
avg_monthly_precip[avg_monthly_precip["precip"] == 1.62]
# Out:
#   months  precip seasons
# 7    Aug    1.62  Summer

# %%
gt2_avg_monthly_precip = avg_monthly_precip[avg_monthly_precip["precip"] > 2.0]

gt2_avg_monthly_precip
# Out:
#   months  precip seasons
# 3    Apr    2.93  Spring
# 4    May    3.05  Spring
# 5   June    2.02  Summer
